# %% [markdown]
# # 01 — Exploratory Data Analysis
# Load the UCI Student Performance dataset and explore.

# %%
import sys, os; sys.path.append(os.path.abspath(".."))
from src.data_loader import load_raw
df = load_raw("both")
print(df.shape)
df.head()

# %%
df.describe(include="all").T

# %%
import seaborn as sns, matplotlib.pyplot as plt
sns.histplot(df["G3"], bins=21); plt.title("G3 distribution"); plt.show()

# %%
sns.boxplot(x="studytime", y="G3", data=df); plt.show()

# %%
sns.boxplot(x="failures", y="G3", data=df); plt.show()
