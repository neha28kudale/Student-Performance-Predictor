# %% [markdown]
# # 03 — Modeling
# Train regression and classification pipelines.

# %%
import sys, os; sys.path.append(os.path.abspath(".."))
from src.train_regression import run as run_reg
from src.train_classification import run as run_clf
reg = run_reg()
clf = run_clf()
print(reg["best_model"], clf["best_model"])

# %%
from src.predict import predict_score, predict_class
sample = {"school":"GP","sex":"F","age":17,"address":"U","famsize":"GT3","Pstatus":"T","Medu":4,"Fedu":4,"Mjob":"teacher","Fjob":"services","reason":"course","guardian":"mother","traveltime":1,"studytime":3,"failures":0,"schoolsup":"no","famsup":"yes","paid":"no","activities":"yes","nursery":"yes","higher":"yes","internet":"yes","romantic":"no","famrel":4,"freetime":3,"goout":2,"Dalc":1,"Walc":1,"health":5,"absences":2,"course":"math"}
print(predict_score(sample)); print(predict_class(sample))
